# %% [markdown]
# # CAPSTONE PROPOSALS

# %%
## LIBRARY IMPORTS ##

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline


import requests
import json
import time
import nltk
import regex as re
from bs4 import BeautifulSoup


from scipy import stats as stats
import statistics

from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV, ElasticNet, LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, plot_roc_curve, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB, BernoulliNB


from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor, RandomForestClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier

# %% [markdown]
# * LoopNet https://www.loopnet.com/
# * CoStar (subscription only)
# * Ten-X https://www.ten-x.com/commercial/search/

# %%
#url = 'https://www.loopnet.com/search/office-buildings/usa/for-sale/?sk=7c46c603c5764d7047e8b3adaee38285&e=u'
#req = requests.get(url)
#req.status_code

# %%
ln_mf = 
ln_off = 
ln_ret = 
ln_ind =
# Out:
#   File "<ipython-input-3-aab43371ed48>", line 1
#     ln_mf =
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## TOPIC 1 - Residential Multifamily Budget Predictor

# %% [markdown]
# #### PROBLEM STATEMENT:
# * Each fiscal year, real estate owners and operators prepare annual property projections, which is often time-intensive. Property budget projections are critical from a manegement perspective, serving as a 'blueprint' to preserve and enhance the underlying real estate value of a property.
#
#
# * Property budgets offer detailed financial data across income and expense line items, and the ability to quickly and accurately project operating expenses for budgetary purposes each year would offer great time-saving utility for asset managers.
#
#
# * Select factors influencing property-level operational costs:
#     * Region / Submarket
#     * Material / Labor Costs
#     * Age / Renovations

# %%
# quarterly acquisition volume, by real estate buyer type
budgets_file = "data/MF_budgets.xlsx"
re_budgets = pd.read_excel(budgets_file, header = 0, index_col = 'Property Name').T
re_budgets.head(50)

# %%
re_budgets.columns

# %%
plt.figure(figsize = (15,15))
ax1 = plt.subplot(311)
sns.scatterplot(x = re_budgets['# of Units'], y = re_budgets['TOTAL OPERATING EXPENSES'])
plt.xticks(range(0, 800, 50))

ax2 = plt.subplot(312)
sns.scatterplot(x = re_budgets['# of Units'], y = re_budgets['Insurance'])
plt.xticks(range(0, 800, 50))

ax3 = plt.subplot(313)
sns.scatterplot(x = re_budgets['# of Units'], y = re_budgets['Real Estate Taxes '])
plt.xticks(range(0, 800, 50));

# %% [markdown]
# ## TOPIC 2 - Real Estate Capital Flow Predictor (Sector / Buyer Type)

# %% [markdown]
# #### PROBLEM STATEMENT:
# * From 2016-2018, real estate investors deployed an average of over \\$500 Billion in capital per year into U.S. commercial real estate properties. As overall real estate transaction volume in the U.S. has swelled in recent years, how will specific property sectors perform over the next decade?
#     * Sale data / valuation metrics - model will attempt to correlate sector / property valuation with broader RE transaction volume
#
#
# * Shifting / evolving societal trends:
#     * Any sectors adversely affected to a greater extent than others during the global pandemic?
#     * Increased wholesale portfolio liquidations due to financial pressure?

# %%
# quarterly acquisition volume, by real estate buyer type
sectors_file = "data/re_sectors_annual.xlsx"
re_sectors = pd.read_excel(sectors_file, header = 0, index_col = 'YR/QTR', dtype = 'int')
re_sectors.head(50)

# %%
re_sectors.columns

# %%
plt.figure(figsize = (15,15))

ax1 = plt.subplot(411)
sns.scatterplot(x = re_sectors.index, y = re_sectors['Total - Total'])
plt.xlabel("Year")
plt.ylabel("Total Tx Volume")
plt.xticks(range(2001, 2019, 1))

ax2 = plt.subplot(412)
sns.scatterplot(x = re_sectors.index, y = re_sectors['Office - Total'])
plt.xlabel("Year")
plt.ylabel("Office Tx Volume")
plt.xticks(range(2001, 2019, 1))

ax3 = plt.subplot(413)
sns.scatterplot(x = re_sectors.index, y = re_sectors['Multifamily - Total'])
plt.xlabel("Year")
plt.ylabel("Multifamily Tx Volume")
plt.xticks(range(2001, 2019, 1))

ax4 = plt.subplot(414)
sns.scatterplot(x = re_sectors.index, y = re_sectors['Retail - Total'])
plt.xlabel("Year")
plt.ylabel("Retail Tx Volume")
plt.xticks(range(2001, 2019, 1));

# %%
buyers_file = "data/re_buyers.csv"
re_buyers = pd.read_csv(buyers_file, index_col = 'Date')
re_buyers.tail(20)

# %% [markdown]
# #### REAL ESTATE DATA SOURCES:
# * Real Capital Analytics (RCA)
# * Industry Research Reports (Wall Street / Big 4)
# * Offering Memorandums (Marketing Package)
# * Green Street Advisors (GSA)
# * Moody’s Analytics (REIS)
#
# * https://www2.deloitte.com/us/en/insights/industry/financial-services/commercial-real-estate-outlook.html

# %% [markdown]
# ## TOPIC 3 - MLB Pitcher Strikeout Predictor

# %% [markdown]
# #### PROBLEM STATEMENT:
# * In recent years, gambling and sports wagering have been legalized at the state-level with increasing frequency. Concurrent with the passage of more welcoming legal regulations, an increasing amount of digital and physical platforms are available to bettors.
# * MLB has a strikeout problem which has created division amongst loyalists of the game and those hoping to promote baseball's popularity in the age of social media via flashy highlights and home runs.
#     * Is it possible to project the ratio of starting pitcher strikeouts in a closed-game environment?
#     * How does this correlate with home runs in the same circumstances?
#     * How do Vegas over / unders respond to these environments?
#     * Pitchers have been using rosin illegally for years, allowing for improved pitch control and spin rate - is this variable capturable somehow?

# %% [markdown]
# #### DATA SOURCES:
# * Baseball Reference
# * Team Rankings
# * MLB Stats
# * ESPN / Sportsline / RotoGrinders

# %% [markdown]
# #### VARIABLES OF INTEREST:
# * Basic metrics
#     * Batting Average / WOBA / OBP
#     * Strikeout Rate (K% / K/9)
#     * Swinging Strike Rate (SwStr%)
# * Advanced metrics
#     * Barrel Rate / Velocity
#     * Launch Trajectory
#     * Swing Speed
#     * Pitch Rotation

# %% [markdown]
# ## DATA IMPORT

# %%
mlb_excel = "data/mlb_test.xlsx"
pitchers = pd.read_excel(mlb_excel, index_col = 'PLAYER')
#index_col = 'YR/QTR', dtype = 'int'

# %%
pitchers.head(20)

# %%
pitchers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Jacob deGrom to Joe Musgrove
# Data columns (total 53 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   $ DK     12 non-null     float64
#  1   INDEX    12 non-null     float64
#  2   TARGET   12 non-null     float64
#  3   PTS/$    12 non-null     float64
#  4   BLEND    12 non-null     float64
#  5   SP-BDR   12 non-null     float64
#  6   OPP      12 non-null     float64
#  7   RUBRIC   12 non-null     float64
#  8   BDR/$    12 non-null     float64
#  9   TEAM     12 non-null     object
#  10  T-O/U    12 non-null     float64
#  11  OPP.1    12 non-null     object
#  12  O-O/U    12 non-null     float64
#  13  H/A      12 non-null     object
#  14  TIME     12 non-null     object
#  15  HR       12 non-null     float64
#  16  BF       12 non-null     float64
#  17  ROLL.    12 non-null     float64
#  18  PROJ.    12 non-null     float64
#  19  B-OPP    12 non-null     float64
# ...

# %%
pitchers.columns
# Out:
# Index(['$ DK', 'INDEX', 'TARGET', 'PTS/$', 'BLEND', 'SP-BDR', 'OPP', 'RUBRIC',
#        'BDR/$', 'TEAM', 'T-O/U', 'OPP.1', 'O-O/U', 'H/A', 'TIME', 'HR', 'BF',
#        'ROLL.', 'PROJ.', 'B-OPP', 'K%', 'BB%', 'xwOBA', 'ISO', 'K%r', 'BB%r',
#        'xwOBAr', 'ISOr', 'K%l', 'BB%l', 'xwOBAl', 'ISOl', 'R', 'S', 'L', 'K%d',
#        'BB%d', 'H-S%', 'LD%', 'xwOBA.1', 'ISO.1', 'SIERA', 'xFIP', 'SPK%',
#        'SWSTR%', 'OPP.2', 'SPAVG', 'OPPAVG', 'SPISO', 'OPPISO', 'ROLL', 'PROJ',
#        'BLEND.1'],
#       dtype='object')

# %%
features_1 = ['BLEND', 'SP-BDR', 'RUBRIC', 'T-O/U', 'O-O/U', 'HR', 'ROLL.', 'PROJ.', 'B-OPP', 'K%', 'BB%', 'xwOBA', 'ISO', 'K%r', 'BB%r','xwOBAr', 'ISOr', 'K%l', 'BB%l', 'xwOBAl', 'ISOl', 'R', 'S', 'L', 'K%d', 'BB%d', 'H-S%', 'LD%', 'ISO.1', 'SIERA', 'xFIP', 'SPK%', 'SWSTR%', 'SPAVG', 'OPPAVG', 'SPISO', 'OPPISO', 'ROLL', 'PROJ', 'BLEND.1']
features_2 = ['TARGET', 'BLEND', 'SP-BDR', 'RUBRIC', 'T-O/U', 'O-O/U', 'HR', 'ROLL.', 'PROJ.', 'B-OPP', 'K%', 'BB%', 'xwOBA', 'ISO', 'K%r', 'BB%r','xwOBAr', 'ISOr', 'K%l', 'BB%l', 'xwOBAl', 'ISOl', 'R', 'S', 'L', 'K%d', 'BB%d', 'H-S%', 'LD%', 'ISO.1', 'SIERA', 'xFIP', 'SPK%', 'SWSTR%', 'SPAVG', 'OPPAVG', 'SPISO', 'OPPISO', 'ROLL', 'PROJ', 'BLEND.1']

# %%
# create correlation variable relative to rest of DataFrame
pitchers_corr = pitchers.corr()[features_1]

# create heatmap to visualize correlation variable
plt.figure(figsize=(20,20))
sns.heatmap(pitchers_corr, annot = True, cmap = 'mako', vmin=-1, vmax=1, linecolor = 'white', linewidth = .005);

# %%
# create correlation variable relative to rest of DataFrame
pitchers_corr_2 = pitchers.corr()[features_2]

# create heatmap to visualize correlation variable
plt.figure(figsize=(20,20))
sns.heatmap(pitchers_corr_2, annot = True, cmap = 'mako', vmin=-1, vmax=1, linecolor = 'white', linewidth = .005);

# %%
# create correlation variable relative to rest of DataFrame
p_target_corr = pitchers.corr()[['TARGET']].sort_values(by = 'TARGET', ascending = False)

# create heatmap to visualize correlation variable
plt.figure(figsize=(20,20))
sns.heatmap(p_target_corr, annot = True, cmap = 'mako', vmin=-1, vmax=1, linecolor = 'white', linewidth = .005);

# %%
#X = pitchers.drop(columns = ['TARGET'])
#y = pitchers['TARGET']

# %%
X = pitchers[features_2]
y = pitchers['TARGET']

print(X.shape)
print(y.shape)
# Out:
# (12, 41)
# (12,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# %%
y_train.value_counts(normalize=True)
# Out:
# 19.955437    0.125
# 10.833680    0.125
# 15.706321    0.125
# 16.206719    0.125
# 19.435382    0.125
# 15.988016    0.125
# 19.754615    0.125
# 13.469561    0.125
# Name: TARGET, dtype: float64

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
# linear Regression
lr = LinearRegression()
lr.fit(X_train_sc, y_train)
lr_preds = lr.predict(X_test_sc)
print(f' Linear Regression Train Score: {lr.score(X_train_sc, y_train)}')
print(f' Linear Regression Test Score: {lr.score(X_test_sc, y_test)}')
# Out:
#  Linear Regression Train Score: 1.0
#  Linear Regression Test Score: -3.493855099529897

# %%
# KNN Regression
knn = KNeighborsRegressor()
knn.fit(X_train_sc, y_train)
knn_preds = knn.predict(X_test_sc)
print(f' KNN Train Score: {knn.score(X_train_sc, y_train)}')
print(f' KNN Test Score: {knn.score(X_test_sc, y_test)}')
# Out:
#  KNN Train Score: 0.4862920976189652
#  KNN Test Score: -2.5459709740757934

# %%
# Decision Tree Regression
dtr = DecisionTreeRegressor()
dtr.fit(X_train_sc, y_train)
dtr_preds = dtr.predict(X_test_sc)
print(f' Decision Tree Train Score: {dtr.score(X_train_sc, y_train)}')
print(f' Decision Tree Test Score: {dtr.score(X_test_sc, y_test)}')
# Out:
#  Decision Tree Train Score: 1.0
#  Decision Tree Test Score: -1.4745227392550078

# %%
# Bagging Regressor
bag = BaggingRegressor()
bag.fit(X_train_sc, y_train)
bag_preds = bag.predict(X_test_sc)
print(f' Bagging Regressor Train Score: {bag.score(X_train_sc, y_train)}')
print(f' Bagging Regressor Test Score: {bag.score(X_test_sc, y_test)}')
# Out:
#  Bagging Regressor Train Score: 0.8438356722934809
#  Bagging Regressor Test Score: -0.5145293462867426

# %%
# Random Forest Regressor
rfr = RandomForestRegressor()
rfr.fit(X_train_sc, y_train)
rfr_preds = rfr.predict(X_test_sc)
print(f' Random Forest Regressor Train Score: {rfr.score(X_train_sc, y_train)}')
print(f' Random Forest Regressor Test Score: {rfr.score(X_test_sc, y_test)}')
# Out:
#  Random Forest Regressor Train Score: 0.894473945726518
#  Random Forest Regressor Test Score: -1.628693678043636

# %%
# AdaBoost Regressor
ada = AdaBoostRegressor()
ada.fit(X_train_sc, y_train)
ada_preds = ada.predict(X_test_sc)
print(f' AdaBoost Train Score: {ada.score(X_train_sc, y_train)}')
print(f' AdaBoost Test Score: {ada.score(X_test_sc, y_test)}')
# Out:
#  AdaBoost Train Score: 0.9994502936481221
#  AdaBoost Test Score: -1.8371424432308383

# %%
# SVR 
svr = SVR()
svr.fit(X_train_sc, y_train)
svr_preds = svr.predict(X_test_sc)
print(f' SVR Train Score: {svr.score(X_train_sc, y_train)}')
print(f' SVR Test Score: {svr.score(X_test_sc, y_test)}')
# Out:
#  SVR Train Score: 0.436581154679446
#  SVR Test Score: -2.0262385068923385
